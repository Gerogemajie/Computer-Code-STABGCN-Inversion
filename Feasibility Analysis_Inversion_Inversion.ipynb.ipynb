# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Dense, Dropout, Conv1D, Conv2D, MaxPooling1D, MaxPooling2D
from tensorflow.keras.layers import Flatten, Reshape, Concatenate, GRU, Bidirectional
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

# %%
# Data loading and preprocessing
xie_1 = pd.read_csv(r'well_log.csv', encoding='ANSI')
print(xie_1.columns)
# Out:
# Index(['CNL_Z', 'Density_0108', 'GR_Z', 'P-wave_0108', 'S-wave_0108'], dtype='object')

# %%
# Normalization (automatic normalization)
scalers = {}  # Dictionary to store scalers for inverse transformation later
for col in xie_1.columns[:13]:
    scaler = MinMaxScaler()  
    xie_1[col] = scaler.fit_transform(xie_1[col].values.reshape(-1,1))
    scalers[col] = scaler  # Store scaler for later use

# %%
# Convert from dataframe to array
xie_1_1 = np.array(xie_1)  # Extract features - xie_1
data = xie_1_1
cnl = data[:,0]   # CNL_Z corresponding to index 0
den = data[:,1]   # Density_0108 corresponding to index 1
gr = data[:,2]    # GR_Z corresponding to index 2
vp = data[:,3]    # P-wave_0108 corresponding to index 3
vs = data[:,4]    # S-wave_0108 corresponding to index 4

vp0 = np.expand_dims(vp, 1)
vs0 = np.expand_dims(vs, 1)
den0 = np.expand_dims(den, 1)
vpvsden = np.concatenate((vp0, vs0, den0), axis=1)
print(vpvsden.shape)

gr0 = np.expand_dims(gr, 1)
cnl0 = np.expand_dims(cnl, 1)
grcnl = np.concatenate((gr0, cnl0), axis=1)
print(grcnl.shape)
# Out:
# (1361, 3)
# (1361, 2)

# %%
# Modified: Create multi-output feature dataset
def create_dataset_multi_output(X, y1, y2, y3, seq_len):
    """
    Create multi-output dataset
    X: input features
    y1: first output (vp)
    y2: second output (vs)
    y3: third output (den)
    seq_len: sequence length
    """
    features = []
    targets_vp = []
    targets_vs = []
    targets_den = []
    
    for i in range(0, len(X) - seq_len, 1):  # 1 is the step size
        data = X[i:i+seq_len]  # Sequence data  
        label_vp = y1[i+seq_len//2]  # vp label data
        label_vs = y2[i+seq_len//2]  # vs label data
        label_den = y3[i+seq_len//2]  # den label data
        # Save to features and labels
        features.append(data)
        targets_vp.append(label_vp)
        targets_vs.append(label_vs)
        targets_den.append(label_den)
    
    # Return
    return np.array(features), np.array(targets_vp), np.array(targets_vs), np.array(targets_den)

# %%
# Sequence length of 9, create new dataset with labels
Len1 = 9
# Modified: use grcnl as input, vp, vs, den as output
(x1, y1_vp, y1_vs, y1_den) = create_dataset_multi_output(grcnl, vp, vs, den, Len1)
print(x1.shape, y1_vp.shape, y1_vs.shape, y1_den.shape)

x1 = x1.reshape(x1.shape[0], x1.shape[1]*x1.shape[2])
print(x1.shape)
# Out:
# (1352, 9, 2) (1352,) (1352,) (1352,)
# (1352, 18)

# %%
# Define multi-output STABGCN model
def build_multi_output_stabgcn_model(input_shape):
    """
    Multi-output STABGCN model for simultaneous VP, VS and DEN prediction
    """
    # Input layer
    inputs = Input(shape=input_shape)
    features = input_shape[0]
    
    # ------- 2D-CNN branch -------
    # Reshape to square image
    side_length = int(np.ceil(np.sqrt(features)))
    padding_needed = side_length * side_length - features
    
    x_padded = tf.pad(inputs, [[0, 0], [0, padding_needed]])
    reshaped_2d = Reshape((side_length, side_length, 1))(x_padded)
    
    # Convolutional layers
    conv2d = Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same',
                   kernel_regularizer=tf.keras.regularizers.l2(0.001))(reshaped_2d)
    pool = MaxPooling2D(pool_size=(2, 2))(conv2d)
    dropout_cnn = Dropout(0.2)(pool)
    cnn_flat = Flatten()(dropout_cnn)
    
    # ------- BiGRU branch -------
    # Build sequence representation
    seq_length = features // 2  # For grcnl, each time step has 2 features (gr, cnl)
    
    # Reshape to sequence
    x_seq = Reshape((seq_length, 2))(inputs[:, :seq_length*2])  # Each time step has 2 features
    
    # BiGRU layer
    bigru = Bidirectional(GRU(32, 
                            recurrent_regularizer=tf.keras.regularizers.l2(0.001),
                            kernel_regularizer=tf.keras.regularizers.l2(0.001)))(x_seq)
    dropout_gru = Dropout(0.2)(bigru)
    
    # Merge features
    merged = Concatenate()([cnn_flat, dropout_gru])
    
    # Shared layers
    shared = Dense(128, activation='relu', 
                  kernel_regularizer=tf.keras.regularizers.l2(0.001))(merged)
    shared_dropout = Dropout(0.2)(shared)
    
    # Branch network - VP prediction
    vp_branch = Dense(64, activation='relu', 
                     kernel_regularizer=tf.keras.regularizers.l2(0.001))(shared_dropout)
    vp_dropout = Dropout(0.2)(vp_branch)
    vp_output = Dense(1, name='vp_output')(vp_dropout)  # VP output
    
    # Branch network - VS prediction
    vs_branch = Dense(64, activation='relu', 
                      kernel_regularizer=tf.keras.regularizers.l2(0.001))(shared_dropout)
    vs_dropout = Dropout(0.2)(vs_branch)
    vs_output = Dense(1, name='vs_output')(vs_dropout)  # VS output
    
    # Branch network - DEN prediction
    den_branch = Dense(64, activation='relu', 
                      kernel_regularizer=tf.keras.regularizers.l2(0.001))(shared_dropout)
    den_dropout = Dropout(0.2)(den_branch)
    den_output = Dense(1, name='den_output')(den_dropout)  # DEN output
    
    # Create model with three outputs
    model = Model(inputs=inputs, outputs=[vp_output, vs_output, den_output])
    
    # Learning rate decay
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate=0.001,
        decay_steps=100,
        decay_rate=0.9)
    
    optimizer = Adam(learning_rate=lr_schedule)
    
    # Compile model with MSE loss for all outputs
    model.compile(
        optimizer=optimizer, 
        loss={'vp_output': 'mse', 'vs_output': 'mse', 'den_output': 'mse'},
        loss_weights={'vp_output': 1.0, 'vs_output': 1.0, 'den_output': 1.0}  # Equal weights for all three outputs
    )
    
    return model

# %%
# Define data shape
features = Len1*2  # Input feature dimensions, Len1*2 (because grcnl has 2 features per time step)
input_shape = (features,)  # Define input shape

# Build model
model3 = build_multi_output_stabgcn_model(input_shape)

# Output model structure
model3.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 18)]                 0         []
#
#  tf.compat.v1.pad (TFOpLamb  (None, 25)                   0         ['input_1[0][0]']
#  da)
#
#  reshape (Reshape)           (None, 5, 5, 1)              0         ['tf.compat.v1.pad[0][0]']
#
#  conv2d (Conv2D)             (None, 5, 5, 32)             320       ['reshape[0][0]']
#
#  tf.__operators__.getitem (  (None, 18)                   0         ['input_1[0][0]']
#  SlicingOpLambda)
#
#  max_pooling2d (MaxPooling2  (None, 2, 2, 32)             0         ['conv2d[0][0]']
#  D)
#
#  reshape_1 (Reshape)         (None, 9, 2)                 0         ['tf.__operators__.getitem[0][
#                                                                     0]']
#
#  dropout (Dropout)           (None, 2, 2, 32)             0         ['max_pooling2d[0][0]']
#
#  bidirectional (Bidirection  (None, 64)                   6912      ['reshape_1[0][0]']
#  al)
#
#  flatten (Flatten)           (None, 128)                  0         ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 64)                   0         ['bidirectional[0][0]']
#
#  concatenate (Concatenate)   (None, 192)                  0         ['flatten[0][0]',
#                                                                      'dropout_1[0][0]']
#
#  dense (Dense)               (None, 128)                  24704     ['concatenate[0][0]']
#
#  dropout_2 (Dropout)         (None, 128)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 64)                   8256      ['dropout_2[0][0]']
#
#  dense_2 (Dense)             (None, 64)                   8256      ['dropout_2[0][0]']
#
#  dense_3 (Dense)             (None, 64)                   8256      ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 64)                   0         ['dense_1[0][0]']
#
#  dropout_4 (Dropout)         (None, 64)                   0         ['dense_2[0][0]']
#
#  dropout_5 (Dropout)         (None, 64)                   0         ['dense_3[0][0]']
#
#  vp_output (Dense)           (None, 1)                    65        ['dropout_3[0][0]']
#
#  vs_output (Dense)           (None, 1)                    65        ['dropout_4[0][0]']
#
#  den_output (Dense)          (None, 1)                    65        ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 56899 (222.26 KB)
# Trainable params: 56899 (222.26 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# Data preparation
source_points = x1
target_points_vp = y1_vp
target_points_vs = y1_vs
target_points_den = y1_den
print(source_points.shape, target_points_vp.shape, target_points_vs.shape, target_points_den.shape)

# Standardize data
scaler = StandardScaler()
source_points_scaled = scaler.fit_transform(source_points)
# Out:
# (1352, 18) (1352,) (1352,) (1352,)

# %%
# Split data into training and testing sets
X_train, X_test, y_train_vp, y_test_vp, y_train_vs, y_test_vs, y_train_den, y_test_den = train_test_split(
    source_points_scaled, target_points_vp, target_points_vs, target_points_den, test_size=0.15, random_state=42
)
print(X_train.shape, X_test.shape, y_train_vp.shape, y_test_vp.shape, y_train_vs.shape, y_test_vs.shape, y_train_den.shape, y_test_den.shape)

# Train model - multi-output
history = model3.fit(
    X_train, 
    {'vp_output': y_train_vp, 'vs_output': y_train_vs, 'den_output': y_train_den}, 
    epochs=150, 
    batch_size=100, 
    validation_split=0.05, 
    verbose=1
)
# Out:
# (1149, 18) (203, 18) (1149,) (203,) (1149,) (203,) (1149,) (203,)
# Epoch 1/150
# 11/11 [==============================] - 7s 133ms/step - loss: 0.7673 - vp_output_loss: 0.1049 - vs_output_loss: 0.0983 - den_output_loss: 0.0887 - val_loss: 0.6176 - val_vp_output_loss: 0.0601 - val_vs_output_loss: 0.0578 - val_den_output_loss: 0.0375
# Epoch 2/150
# 11/11 [==============================] - 0s 18ms/step - loss: 0.6187 - vp_output_loss: 0.0619 - vs_output_loss: 0.0585 - den_output_loss: 0.0475 - val_loss: 0.5322 - val_vp_output_loss: 0.0309 - val_vs_output_loss: 0.0306 - val_den_output_loss: 0.0336
# Epoch 3/150
# 11/11 [==============================] - 0s 15ms/step - loss: 0.5493 - vp_output_loss: 0.0443 - vs_output_loss: 0.0432 - den_output_loss: 0.0358 - val_loss: 0.4872 - val_vp_output_loss: 0.0290 - val_vs_output_loss: 0.0262 - val_den_output_loss: 0.0197
# Epoch 4/150
# 11/11 [==============================] - 0s 12ms/step - loss: 0.4983 - vp_output_loss: 0.0343 - vs_output_loss: 0.0355 - den_output_loss: 0.0269 - val_loss: 0.4461 - val_vp_output_loss: 0.0200 - val_vs_output_loss: 0.0212 - val_den_output_loss: 0.0163
# Epoch 5/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.4565 - vp_output_loss: 0.0268 - vs_output_loss: 0.0293 - den_output_loss: 0.0218 - val_loss: 0.4044 - val_vp_output_loss: 0.0130 - val_vs_output_loss: 0.0136 - val_den_output_loss: 0.0114
# Epoch 6/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.4221 - vp_output_loss: 0.0240 - vs_output_loss: 0.0233 - den_output_loss: 0.0177 - val_loss: 0.3755 - val_vp_output_loss: 0.0102 - val_vs_output_loss: 0.0112 - val_den_output_loss: 0.0084
# Epoch 7/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.3950 - vp_output_loss: 0.0201 - vs_output_loss: 0.0226 - den_output_loss: 0.0153 - val_loss: 0.3545 - val_vp_output_loss: 0.0101 - val_vs_output_loss: 0.0105 - val_den_output_loss: 0.0074
# Epoch 8/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.3666 - vp_output_loss: 0.0168 - vs_output_loss: 0.0179 - den_output_loss: 0.0135 - val_loss: 0.3309 - val_vp_output_loss: 0.0071 - val_vs_output_loss: 0.0085 - val_den_output_loss: 0.0065
# Epoch 9/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.3474 - vp_output_loss: 0.0158 - vs_output_loss: 0.0170 - den_output_loss: 0.0134 - val_loss: 0.3160 - val_vp_output_loss: 0.0084 - val_vs_output_loss: 0.0095 - val_den_output_loss: 0.0059
# Epoch 10/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.3300 - vp_output_loss: 0.0158 - vs_output_loss: 0.0172 - den_output_loss: 0.0117 - val_loss: 0.3019 - val_vp_output_loss: 0.0083 - val_vs_output_loss: 0.0097 - val_den_output_loss: 0.0070
# Epoch 11/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.3134 - vp_output_loss: 0.0146 - vs_output_loss: 0.0163 - den_output_loss: 0.0121 - val_loss: 0.2835 - val_vp_output_loss: 0.0064 - val_vs_output_loss: 0.0085 - val_den_output_loss: 0.0060
# Epoch 12/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.2973 - vp_output_loss: 0.0146 - vs_output_loss: 0.0161 - den_output_loss: 0.0100 - val_loss: 0.2707 - val_vp_output_loss: 0.0071 - val_vs_output_loss: 0.0084 - val_den_output_loss: 0.0057
# Epoch 13/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.2826 - vp_output_loss: 0.0138 - vs_output_loss: 0.0144 - den_output_loss: 0.0105 - val_loss: 0.2596 - val_vp_output_loss: 0.0077 - val_vs_output_loss: 0.0084 - val_den_output_loss: 0.0063
# Epoch 14/150
# 11/11 [==============================] - 0s 11ms/step - loss: 0.2701 - vp_output_loss: 0.0129 - vs_output_loss: 0.0150 - den_output_loss: 0.0101 - val_loss: 0.2452 - val_vp_output_loss: 0.0059 - val_vs_output_loss: 0.0078 - val_den_output_loss: 0.0057
# Epoch 15/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.2579 - vp_output_loss: 0.0137 - vs_output_loss: 0.0139 - den_output_loss: 0.0093 - val_loss: 0.2367 - val_vp_output_loss: 0.0076 - val_vs_output_loss: 0.0081 - val_den_output_loss: 0.0059
# Epoch 16/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.2457 - vp_output_loss: 0.0131 - vs_output_loss: 0.0133 - den_output_loss: 0.0086 - val_loss: 0.2253 - val_vp_output_loss: 0.0064 - val_vs_output_loss: 0.0079 - val_den_output_loss: 0.0056
# Epoch 17/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.2360 - vp_output_loss: 0.0125 - vs_output_loss: 0.0137 - den_output_loss: 0.0087 - val_loss: 0.2161 - val_vp_output_loss: 0.0064 - val_vs_output_loss: 0.0081 - val_den_output_loss: 0.0055
# Epoch 18/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.2251 - vp_output_loss: 0.0117 - vs_output_loss: 0.0129 - den_output_loss: 0.0083 - val_loss: 0.2064 - val_vp_output_loss: 0.0056 - val_vs_output_loss: 0.0079 - val_den_output_loss: 0.0054
# Epoch 19/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.2173 - vp_output_loss: 0.0120 - vs_output_loss: 0.0133 - den_output_loss: 0.0083 - val_loss: 0.1988 - val_vp_output_loss: 0.0062 - val_vs_output_loss: 0.0081 - val_den_output_loss: 0.0052
# Epoch 20/150
# 11/11 [==============================] - 0s 14ms/step - loss: 0.2080 - vp_output_loss: 0.0121 - vs_output_loss: 0.0120 - den_output_loss: 0.0081 - val_loss: 0.1912 - val_vp_output_loss: 0.0061 - val_vs_output_loss: 0.0081 - val_den_output_loss: 0.0053
# Epoch 21/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.2001 - vp_output_loss: 0.0121 - vs_output_loss: 0.0118 - den_output_loss: 0.0078 - val_loss: 0.1838 - val_vp_output_loss: 0.0061 - val_vs_output_loss: 0.0080 - val_den_output_loss: 0.0052
# Epoch 22/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.1933 - vp_output_loss: 0.0119 - vs_output_loss: 0.0122 - den_output_loss: 0.0077 - val_loss: 0.1776 - val_vp_output_loss: 0.0061 - val_vs_output_loss: 0.0085 - val_den_output_loss: 0.0052
# Epoch 23/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1863 - vp_output_loss: 0.0118 - vs_output_loss: 0.0116 - den_output_loss: 0.0081 - val_loss: 0.1703 - val_vp_output_loss: 0.0059 - val_vs_output_loss: 0.0076 - val_den_output_loss: 0.0053
# Epoch 24/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1796 - vp_output_loss: 0.0119 - vs_output_loss: 0.0114 - den_output_loss: 0.0076 - val_loss: 0.1650 - val_vp_output_loss: 0.0064 - val_vs_output_loss: 0.0080 - val_den_output_loss: 0.0052
# Epoch 25/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1737 - vp_output_loss: 0.0115 - vs_output_loss: 0.0119 - den_output_loss: 0.0075 - val_loss: 0.1591 - val_vp_output_loss: 0.0059 - val_vs_output_loss: 0.0081 - val_den_output_loss: 0.0052
# Epoch 26/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.1679 - vp_output_loss: 0.0113 - vs_output_loss: 0.0116 - den_output_loss: 0.0075 - val_loss: 0.1530 - val_vp_output_loss: 0.0055 - val_vs_output_loss: 0.0079 - val_den_output_loss: 0.0051
# Epoch 27/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1625 - vp_output_loss: 0.0115 - vs_output_loss: 0.0114 - den_output_loss: 0.0074 - val_loss: 0.1481 - val_vp_output_loss: 0.0058 - val_vs_output_loss: 0.0077 - val_den_output_loss: 0.0051
# Epoch 28/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1571 - vp_output_loss: 0.0110 - vs_output_loss: 0.0115 - den_output_loss: 0.0073 - val_loss: 0.1431 - val_vp_output_loss: 0.0056 - val_vs_output_loss: 0.0078 - val_den_output_loss: 0.0050
# Epoch 29/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.1510 - vp_output_loss: 0.0113 - vs_output_loss: 0.0106 - den_output_loss: 0.0065 - val_loss: 0.1385 - val_vp_output_loss: 0.0057 - val_vs_output_loss: 0.0078 - val_den_output_loss: 0.0049
# Epoch 30/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.1463 - vp_output_loss: 0.0107 - vs_output_loss: 0.0112 - den_output_loss: 0.0063 - val_loss: 0.1351 - val_vp_output_loss: 0.0060 - val_vs_output_loss: 0.0081 - val_den_output_loss: 0.0050
# Epoch 31/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.1421 - vp_output_loss: 0.0110 - vs_output_loss: 0.0102 - den_output_loss: 0.0069 - val_loss: 0.1298 - val_vp_output_loss: 0.0053 - val_vs_output_loss: 0.0078 - val_den_output_loss: 0.0049
# Epoch 32/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1388 - vp_output_loss: 0.0109 - vs_output_loss: 0.0111 - den_output_loss: 0.0067 - val_loss: 0.1258 - val_vp_output_loss: 0.0054 - val_vs_output_loss: 0.0076 - val_den_output_loss: 0.0048
# Epoch 33/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1333 - vp_output_loss: 0.0096 - vs_output_loss: 0.0106 - den_output_loss: 0.0069 - val_loss: 0.1226 - val_vp_output_loss: 0.0054 - val_vs_output_loss: 0.0080 - val_den_output_loss: 0.0049
# Epoch 34/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.1310 - vp_output_loss: 0.0109 - vs_output_loss: 0.0106 - den_output_loss: 0.0068 - val_loss: 0.1181 - val_vp_output_loss: 0.0051 - val_vs_output_loss: 0.0074 - val_den_output_loss: 0.0048
# Epoch 35/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.1270 - vp_output_loss: 0.0103 - vs_output_loss: 0.0105 - den_output_loss: 0.0069 - val_loss: 0.1160 - val_vp_output_loss: 0.0058 - val_vs_output_loss: 0.0077 - val_den_output_loss: 0.0050
# Epoch 36/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.1239 - vp_output_loss: 0.0107 - vs_output_loss: 0.0105 - den_output_loss: 0.0066 - val_loss: 0.1123 - val_vp_output_loss: 0.0055 - val_vs_output_loss: 0.0076 - val_den_output_loss: 0.0050
# Epoch 37/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.1204 - vp_output_loss: 0.0112 - vs_output_loss: 0.0097 - den_output_loss: 0.0066 - val_loss: 0.1087 - val_vp_output_loss: 0.0051 - val_vs_output_loss: 0.0075 - val_den_output_loss: 0.0047
# Epoch 38/150
# 11/11 [==============================] - 0s 13ms/step - loss: 0.1178 - vp_output_loss: 0.0104 - vs_output_loss: 0.0110 - den_output_loss: 0.0064 - val_loss: 0.1064 - val_vp_output_loss: 0.0055 - val_vs_output_loss: 0.0076 - val_den_output_loss: 0.0049
# Epoch 39/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1138 - vp_output_loss: 0.0101 - vs_output_loss: 0.0099 - den_output_loss: 0.0067 - val_loss: 0.1036 - val_vp_output_loss: 0.0055 - val_vs_output_loss: 0.0076 - val_den_output_loss: 0.0048
# Epoch 40/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1114 - vp_output_loss: 0.0104 - vs_output_loss: 0.0099 - den_output_loss: 0.0066 - val_loss: 0.1006 - val_vp_output_loss: 0.0051 - val_vs_output_loss: 0.0077 - val_den_output_loss: 0.0049
# Epoch 41/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.1092 - vp_output_loss: 0.0104 - vs_output_loss: 0.0101 - den_output_loss: 0.0068 - val_loss: 0.0988 - val_vp_output_loss: 0.0057 - val_vs_output_loss: 0.0077 - val_den_output_loss: 0.0049
# Epoch 42/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1069 - vp_output_loss: 0.0105 - vs_output_loss: 0.0107 - den_output_loss: 0.0063 - val_loss: 0.0961 - val_vp_output_loss: 0.0056 - val_vs_output_loss: 0.0076 - val_den_output_loss: 0.0049
# Epoch 43/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1037 - vp_output_loss: 0.0101 - vs_output_loss: 0.0102 - den_output_loss: 0.0064 - val_loss: 0.0934 - val_vp_output_loss: 0.0052 - val_vs_output_loss: 0.0075 - val_den_output_loss: 0.0049
# Epoch 44/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1014 - vp_output_loss: 0.0101 - vs_output_loss: 0.0104 - den_output_loss: 0.0061 - val_loss: 0.0912 - val_vp_output_loss: 0.0053 - val_vs_output_loss: 0.0075 - val_den_output_loss: 0.0048
# Epoch 45/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0993 - vp_output_loss: 0.0105 - vs_output_loss: 0.0095 - den_output_loss: 0.0066 - val_loss: 0.0891 - val_vp_output_loss: 0.0051 - val_vs_output_loss: 0.0077 - val_den_output_loss: 0.0048
# Epoch 46/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0964 - vp_output_loss: 0.0102 - vs_output_loss: 0.0096 - den_output_loss: 0.0061 - val_loss: 0.0869 - val_vp_output_loss: 0.0052 - val_vs_output_loss: 0.0074 - val_den_output_loss: 0.0048
# Epoch 47/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0943 - vp_output_loss: 0.0097 - vs_output_loss: 0.0095 - den_output_loss: 0.0065 - val_loss: 0.0850 - val_vp_output_loss: 0.0051 - val_vs_output_loss: 0.0075 - val_den_output_loss: 0.0049
# Epoch 48/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0930 - vp_output_loss: 0.0101 - vs_output_loss: 0.0101 - den_output_loss: 0.0060 - val_loss: 0.0830 - val_vp_output_loss: 0.0050 - val_vs_output_loss: 0.0074 - val_den_output_loss: 0.0049
# Epoch 49/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0907 - vp_output_loss: 0.0098 - vs_output_loss: 0.0097 - den_output_loss: 0.0062 - val_loss: 0.0820 - val_vp_output_loss: 0.0055 - val_vs_output_loss: 0.0077 - val_den_output_loss: 0.0048
# Epoch 50/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0887 - vp_output_loss: 0.0097 - vs_output_loss: 0.0097 - den_output_loss: 0.0061 - val_loss: 0.0794 - val_vp_output_loss: 0.0051 - val_vs_output_loss: 0.0073 - val_den_output_loss: 0.0048
# Epoch 51/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0874 - vp_output_loss: 0.0096 - vs_output_loss: 0.0098 - den_output_loss: 0.0065 - val_loss: 0.0787 - val_vp_output_loss: 0.0054 - val_vs_output_loss: 0.0077 - val_den_output_loss: 0.0050
# Epoch 52/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0857 - vp_output_loss: 0.0101 - vs_output_loss: 0.0095 - den_output_loss: 0.0062 - val_loss: 0.0763 - val_vp_output_loss: 0.0050 - val_vs_output_loss: 0.0074 - val_den_output_loss: 0.0049
# Epoch 53/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0838 - vp_output_loss: 0.0096 - vs_output_loss: 0.0101 - den_output_loss: 0.0058 - val_loss: 0.0750 - val_vp_output_loss: 0.0051 - val_vs_output_loss: 0.0075 - val_den_output_loss: 0.0049
# Epoch 54/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0827 - vp_output_loss: 0.0101 - vs_output_loss: 0.0095 - den_output_loss: 0.0063 - val_loss: 0.0734 - val_vp_output_loss: 0.0052 - val_vs_output_loss: 0.0074 - val_den_output_loss: 0.0048
# Epoch 55/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0812 - vp_output_loss: 0.0097 - vs_output_loss: 0.0097 - den_output_loss: 0.0064 - val_loss: 0.0719 - val_vp_output_loss: 0.0050 - val_vs_output_loss: 0.0074 - val_den_output_loss: 0.0049
# Epoch 56/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0800 - vp_output_loss: 0.0099 - vs_output_loss: 0.0100 - den_output_loss: 0.0061 - val_loss: 0.0705 - val_vp_output_loss: 0.0050 - val_vs_output_loss: 0.0074 - val_den_output_loss: 0.0048
# Epoch 57/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0784 - vp_output_loss: 0.0097 - vs_output_loss: 0.0100 - den_output_loss: 0.0061 - val_loss: 0.0694 - val_vp_output_loss: 0.0051 - val_vs_output_loss: 0.0075 - val_den_output_loss: 0.0048
# Epoch 58/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0775 - vp_output_loss: 0.0099 - vs_output_loss: 0.0100 - den_output_loss: 0.0062 - val_loss: 0.0688 - val_vp_output_loss: 0.0052 - val_vs_output_loss: 0.0078 - val_den_output_loss: 0.0050
# Epoch 59/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0747 - vp_output_loss: 0.0093 - vs_output_loss: 0.0092 - den_output_loss: 0.0060 - val_loss: 0.0666 - val_vp_output_loss: 0.0050 - val_vs_output_loss: 0.0073 - val_den_output_loss: 0.0048
# Epoch 60/150
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0751 - vp_output_loss: 0.0099 - vs_output_loss: 0.0103 - den_output_loss: 0.0059 - val_loss: 0.0663 - val_vp_output_loss: 0.0055 - val_vs_output_loss: 0.0076 - val_den_output_loss: 0.0050
# Epoch 61/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0737 - vp_output_loss: 0.0101 - vs_output_loss: 0.0097 - den_output_loss: 0.0061 - val_loss: 0.0643 - val_vp_output_loss: 0.0051 - val_vs_output_loss: 0.0073 - val_den_output_loss: 0.0047
# Epoch 62/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0726 - vp_output_loss: 0.0099 - vs_output_loss: 0.0098 - den_output_loss: 0.0062 - val_loss: 0.0643 - val_vp_output_loss: 0.0055 - val_vs_output_loss: 0.0077 - val_den_output_loss: 0.0049
# Epoch 63/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0714 - vp_output_loss: 0.0094 - vs_output_loss: 0.0101 - den_output_loss: 0.0062 - val_loss: 0.0624 - val_vp_output_loss: 0.0051 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0049
# Epoch 64/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0694 - vp_output_loss: 0.0092 - vs_output_loss: 0.0095 - den_output_loss: 0.0061 - val_loss: 0.0614 - val_vp_output_loss: 0.0051 - val_vs_output_loss: 0.0073 - val_den_output_loss: 0.0048
# Epoch 65/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0691 - vp_output_loss: 0.0096 - vs_output_loss: 0.0099 - den_output_loss: 0.0060 - val_loss: 0.0606 - val_vp_output_loss: 0.0052 - val_vs_output_loss: 0.0074 - val_den_output_loss: 0.0048
# Epoch 66/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0685 - vp_output_loss: 0.0101 - vs_output_loss: 0.0096 - den_output_loss: 0.0060 - val_loss: 0.0594 - val_vp_output_loss: 0.0051 - val_vs_output_loss: 0.0073 - val_den_output_loss: 0.0048
# Epoch 67/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0672 - vp_output_loss: 0.0098 - vs_output_loss: 0.0095 - den_output_loss: 0.0061 - val_loss: 0.0586 - val_vp_output_loss: 0.0051 - val_vs_output_loss: 0.0073 - val_den_output_loss: 0.0048
# Epoch 68/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0656 - vp_output_loss: 0.0095 - vs_output_loss: 0.0094 - den_output_loss: 0.0058 - val_loss: 0.0574 - val_vp_output_loss: 0.0050 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0048
# Epoch 69/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0644 - vp_output_loss: 0.0094 - vs_output_loss: 0.0091 - den_output_loss: 0.0059 - val_loss: 0.0569 - val_vp_output_loss: 0.0051 - val_vs_output_loss: 0.0074 - val_den_output_loss: 0.0048
# Epoch 70/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0637 - vp_output_loss: 0.0094 - vs_output_loss: 0.0091 - den_output_loss: 0.0061 - val_loss: 0.0559 - val_vp_output_loss: 0.0050 - val_vs_output_loss: 0.0073 - val_den_output_loss: 0.0049
# Epoch 71/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0636 - vp_output_loss: 0.0094 - vs_output_loss: 0.0098 - den_output_loss: 0.0060 - val_loss: 0.0554 - val_vp_output_loss: 0.0051 - val_vs_output_loss: 0.0075 - val_den_output_loss: 0.0048
# Epoch 72/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0628 - vp_output_loss: 0.0098 - vs_output_loss: 0.0096 - den_output_loss: 0.0058 - val_loss: 0.0548 - val_vp_output_loss: 0.0052 - val_vs_output_loss: 0.0074 - val_den_output_loss: 0.0050
# Epoch 73/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0606 - vp_output_loss: 0.0087 - vs_output_loss: 0.0093 - den_output_loss: 0.0056 - val_loss: 0.0536 - val_vp_output_loss: 0.0049 - val_vs_output_loss: 0.0074 - val_den_output_loss: 0.0049
# Epoch 74/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0615 - vp_output_loss: 0.0101 - vs_output_loss: 0.0091 - den_output_loss: 0.0061 - val_loss: 0.0533 - val_vp_output_loss: 0.0053 - val_vs_output_loss: 0.0073 - val_den_output_loss: 0.0049
# Epoch 75/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0601 - vp_output_loss: 0.0095 - vs_output_loss: 0.0092 - den_output_loss: 0.0059 - val_loss: 0.0523 - val_vp_output_loss: 0.0050 - val_vs_output_loss: 0.0074 - val_den_output_loss: 0.0048
# Epoch 76/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0594 - vp_output_loss: 0.0098 - vs_output_loss: 0.0094 - den_output_loss: 0.0054 - val_loss: 0.0515 - val_vp_output_loss: 0.0050 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0049
# Epoch 77/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0593 - vp_output_loss: 0.0099 - vs_output_loss: 0.0093 - den_output_loss: 0.0059 - val_loss: 0.0515 - val_vp_output_loss: 0.0053 - val_vs_output_loss: 0.0075 - val_den_output_loss: 0.0049
# Epoch 78/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0588 - vp_output_loss: 0.0099 - vs_output_loss: 0.0095 - den_output_loss: 0.0060 - val_loss: 0.0500 - val_vp_output_loss: 0.0048 - val_vs_output_loss: 0.0073 - val_den_output_loss: 0.0047
# Epoch 79/150
# 11/11 [==============================] - 0s 14ms/step - loss: 0.0567 - vp_output_loss: 0.0094 - vs_output_loss: 0.0083 - den_output_loss: 0.0061 - val_loss: 0.0502 - val_vp_output_loss: 0.0052 - val_vs_output_loss: 0.0075 - val_den_output_loss: 0.0049
# Epoch 80/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0561 - vp_output_loss: 0.0092 - vs_output_loss: 0.0088 - den_output_loss: 0.0059 - val_loss: 0.0488 - val_vp_output_loss: 0.0049 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0047
# Epoch 81/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0566 - vp_output_loss: 0.0096 - vs_output_loss: 0.0093 - den_output_loss: 0.0060 - val_loss: 0.0491 - val_vp_output_loss: 0.0053 - val_vs_output_loss: 0.0075 - val_den_output_loss: 0.0048
# Epoch 82/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0550 - vp_output_loss: 0.0093 - vs_output_loss: 0.0091 - den_output_loss: 0.0055 - val_loss: 0.0480 - val_vp_output_loss: 0.0049 - val_vs_output_loss: 0.0074 - val_den_output_loss: 0.0049
# Epoch 83/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0550 - vp_output_loss: 0.0098 - vs_output_loss: 0.0091 - den_output_loss: 0.0055 - val_loss: 0.0480 - val_vp_output_loss: 0.0053 - val_vs_output_loss: 0.0077 - val_den_output_loss: 0.0048
# Epoch 84/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0542 - vp_output_loss: 0.0094 - vs_output_loss: 0.0089 - den_output_loss: 0.0059 - val_loss: 0.0467 - val_vp_output_loss: 0.0048 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0048
# Epoch 85/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0537 - vp_output_loss: 0.0093 - vs_output_loss: 0.0090 - den_output_loss: 0.0059 - val_loss: 0.0464 - val_vp_output_loss: 0.0049 - val_vs_output_loss: 0.0074 - val_den_output_loss: 0.0048
# Epoch 86/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0542 - vp_output_loss: 0.0099 - vs_output_loss: 0.0096 - den_output_loss: 0.0057 - val_loss: 0.0463 - val_vp_output_loss: 0.0052 - val_vs_output_loss: 0.0074 - val_den_output_loss: 0.0049
# Epoch 87/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0530 - vp_output_loss: 0.0093 - vs_output_loss: 0.0095 - den_output_loss: 0.0057 - val_loss: 0.0449 - val_vp_output_loss: 0.0047 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0047
# Epoch 88/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0528 - vp_output_loss: 0.0094 - vs_output_loss: 0.0095 - den_output_loss: 0.0058 - val_loss: 0.0452 - val_vp_output_loss: 0.0051 - val_vs_output_loss: 0.0074 - val_den_output_loss: 0.0049
# Epoch 89/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0514 - vp_output_loss: 0.0093 - vs_output_loss: 0.0087 - den_output_loss: 0.0058 - val_loss: 0.0442 - val_vp_output_loss: 0.0049 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0047
# Epoch 90/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0514 - vp_output_loss: 0.0092 - vs_output_loss: 0.0090 - den_output_loss: 0.0061 - val_loss: 0.0442 - val_vp_output_loss: 0.0051 - val_vs_output_loss: 0.0073 - val_den_output_loss: 0.0049
# Epoch 91/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0510 - vp_output_loss: 0.0094 - vs_output_loss: 0.0091 - den_output_loss: 0.0057 - val_loss: 0.0430 - val_vp_output_loss: 0.0046 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0047
# Epoch 92/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0506 - vp_output_loss: 0.0094 - vs_output_loss: 0.0091 - den_output_loss: 0.0058 - val_loss: 0.0433 - val_vp_output_loss: 0.0051 - val_vs_output_loss: 0.0073 - val_den_output_loss: 0.0048
# Epoch 93/150
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0495 - vp_output_loss: 0.0091 - vs_output_loss: 0.0090 - den_output_loss: 0.0055 - val_loss: 0.0423 - val_vp_output_loss: 0.0046 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0047
# Epoch 94/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0503 - vp_output_loss: 0.0094 - vs_output_loss: 0.0096 - den_output_loss: 0.0059 - val_loss: 0.0425 - val_vp_output_loss: 0.0050 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0050
# Epoch 95/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0488 - vp_output_loss: 0.0090 - vs_output_loss: 0.0092 - den_output_loss: 0.0056 - val_loss: 0.0418 - val_vp_output_loss: 0.0048 - val_vs_output_loss: 0.0073 - val_den_output_loss: 0.0048
# Epoch 96/150
# 11/11 [==============================] - 0s 13ms/step - loss: 0.0489 - vp_output_loss: 0.0093 - vs_output_loss: 0.0091 - den_output_loss: 0.0057 - val_loss: 0.0413 - val_vp_output_loss: 0.0049 - val_vs_output_loss: 0.0071 - val_den_output_loss: 0.0047
# Epoch 97/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0485 - vp_output_loss: 0.0094 - vs_output_loss: 0.0089 - den_output_loss: 0.0057 - val_loss: 0.0416 - val_vp_output_loss: 0.0050 - val_vs_output_loss: 0.0074 - val_den_output_loss: 0.0050
# Epoch 98/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0474 - vp_output_loss: 0.0092 - vs_output_loss: 0.0085 - den_output_loss: 0.0057 - val_loss: 0.0407 - val_vp_output_loss: 0.0048 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0048
# Epoch 99/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0468 - vp_output_loss: 0.0089 - vs_output_loss: 0.0086 - den_output_loss: 0.0055 - val_loss: 0.0405 - val_vp_output_loss: 0.0049 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0048
# Epoch 100/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0469 - vp_output_loss: 0.0092 - vs_output_loss: 0.0087 - den_output_loss: 0.0056 - val_loss: 0.0405 - val_vp_output_loss: 0.0049 - val_vs_output_loss: 0.0075 - val_den_output_loss: 0.0048
# Epoch 101/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0467 - vp_output_loss: 0.0091 - vs_output_loss: 0.0088 - den_output_loss: 0.0057 - val_loss: 0.0400 - val_vp_output_loss: 0.0049 - val_vs_output_loss: 0.0073 - val_den_output_loss: 0.0049
# Epoch 102/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0463 - vp_output_loss: 0.0091 - vs_output_loss: 0.0088 - den_output_loss: 0.0057 - val_loss: 0.0398 - val_vp_output_loss: 0.0050 - val_vs_output_loss: 0.0074 - val_den_output_loss: 0.0048
# Epoch 103/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0456 - vp_output_loss: 0.0090 - vs_output_loss: 0.0085 - den_output_loss: 0.0057 - val_loss: 0.0389 - val_vp_output_loss: 0.0047 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0049
# Epoch 104/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0455 - vp_output_loss: 0.0087 - vs_output_loss: 0.0090 - den_output_loss: 0.0057 - val_loss: 0.0391 - val_vp_output_loss: 0.0049 - val_vs_output_loss: 0.0074 - val_den_output_loss: 0.0048
# Epoch 105/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0457 - vp_output_loss: 0.0092 - vs_output_loss: 0.0091 - den_output_loss: 0.0056 - val_loss: 0.0386 - val_vp_output_loss: 0.0049 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0048
# Epoch 106/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0448 - vp_output_loss: 0.0088 - vs_output_loss: 0.0088 - den_output_loss: 0.0057 - val_loss: 0.0385 - val_vp_output_loss: 0.0050 - val_vs_output_loss: 0.0074 - val_den_output_loss: 0.0048
# Epoch 107/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0451 - vp_output_loss: 0.0093 - vs_output_loss: 0.0087 - den_output_loss: 0.0058 - val_loss: 0.0378 - val_vp_output_loss: 0.0048 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0048
# Epoch 108/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0440 - vp_output_loss: 0.0090 - vs_output_loss: 0.0084 - den_output_loss: 0.0056 - val_loss: 0.0377 - val_vp_output_loss: 0.0049 - val_vs_output_loss: 0.0071 - val_den_output_loss: 0.0049
# Epoch 109/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0447 - vp_output_loss: 0.0093 - vs_output_loss: 0.0092 - den_output_loss: 0.0055 - val_loss: 0.0372 - val_vp_output_loss: 0.0047 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0048
# Epoch 110/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0435 - vp_output_loss: 0.0089 - vs_output_loss: 0.0088 - den_output_loss: 0.0054 - val_loss: 0.0372 - val_vp_output_loss: 0.0049 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0049
# Epoch 111/150
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0427 - vp_output_loss: 0.0087 - vs_output_loss: 0.0082 - den_output_loss: 0.0056 - val_loss: 0.0368 - val_vp_output_loss: 0.0047 - val_vs_output_loss: 0.0073 - val_den_output_loss: 0.0048
# Epoch 112/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0431 - vp_output_loss: 0.0090 - vs_output_loss: 0.0084 - den_output_loss: 0.0058 - val_loss: 0.0370 - val_vp_output_loss: 0.0051 - val_vs_output_loss: 0.0073 - val_den_output_loss: 0.0049
# Epoch 113/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0431 - vp_output_loss: 0.0092 - vs_output_loss: 0.0086 - den_output_loss: 0.0056 - val_loss: 0.0361 - val_vp_output_loss: 0.0047 - val_vs_output_loss: 0.0071 - val_den_output_loss: 0.0048
# Epoch 114/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0425 - vp_output_loss: 0.0089 - vs_output_loss: 0.0087 - den_output_loss: 0.0054 - val_loss: 0.0362 - val_vp_output_loss: 0.0049 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0049
# Epoch 115/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0425 - vp_output_loss: 0.0088 - vs_output_loss: 0.0086 - den_output_loss: 0.0058 - val_loss: 0.0363 - val_vp_output_loss: 0.0050 - val_vs_output_loss: 0.0073 - val_den_output_loss: 0.0049
# Epoch 116/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0427 - vp_output_loss: 0.0093 - vs_output_loss: 0.0089 - den_output_loss: 0.0055 - val_loss: 0.0357 - val_vp_output_loss: 0.0048 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0047
# Epoch 117/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0413 - vp_output_loss: 0.0087 - vs_output_loss: 0.0085 - den_output_loss: 0.0053 - val_loss: 0.0357 - val_vp_output_loss: 0.0049 - val_vs_output_loss: 0.0073 - val_den_output_loss: 0.0048
# Epoch 118/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0421 - vp_output_loss: 0.0091 - vs_output_loss: 0.0087 - den_output_loss: 0.0057 - val_loss: 0.0351 - val_vp_output_loss: 0.0047 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0048
# Epoch 119/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0412 - vp_output_loss: 0.0088 - vs_output_loss: 0.0086 - den_output_loss: 0.0054 - val_loss: 0.0351 - val_vp_output_loss: 0.0048 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0048
# Epoch 120/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0408 - vp_output_loss: 0.0088 - vs_output_loss: 0.0083 - den_output_loss: 0.0055 - val_loss: 0.0349 - val_vp_output_loss: 0.0048 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0048
# Epoch 121/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0417 - vp_output_loss: 0.0094 - vs_output_loss: 0.0088 - den_output_loss: 0.0056 - val_loss: 0.0346 - val_vp_output_loss: 0.0047 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0048
# Epoch 122/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0416 - vp_output_loss: 0.0089 - vs_output_loss: 0.0089 - den_output_loss: 0.0059 - val_loss: 0.0346 - val_vp_output_loss: 0.0049 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0048
# Epoch 123/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0414 - vp_output_loss: 0.0090 - vs_output_loss: 0.0091 - den_output_loss: 0.0057 - val_loss: 0.0342 - val_vp_output_loss: 0.0048 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0048
# Epoch 124/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0408 - vp_output_loss: 0.0088 - vs_output_loss: 0.0088 - den_output_loss: 0.0057 - val_loss: 0.0345 - val_vp_output_loss: 0.0049 - val_vs_output_loss: 0.0073 - val_den_output_loss: 0.0049
# Epoch 125/150
# 11/11 [==============================] - 0s 13ms/step - loss: 0.0404 - vp_output_loss: 0.0091 - vs_output_loss: 0.0087 - den_output_loss: 0.0054 - val_loss: 0.0341 - val_vp_output_loss: 0.0049 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0048
# Epoch 126/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0398 - vp_output_loss: 0.0087 - vs_output_loss: 0.0085 - den_output_loss: 0.0055 - val_loss: 0.0335 - val_vp_output_loss: 0.0047 - val_vs_output_loss: 0.0071 - val_den_output_loss: 0.0048
# Epoch 127/150
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0406 - vp_output_loss: 0.0092 - vs_output_loss: 0.0088 - den_output_loss: 0.0057 - val_loss: 0.0337 - val_vp_output_loss: 0.0050 - val_vs_output_loss: 0.0071 - val_den_output_loss: 0.0049
# Epoch 128/150
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0395 - vp_output_loss: 0.0089 - vs_output_loss: 0.0086 - den_output_loss: 0.0054 - val_loss: 0.0335 - val_vp_output_loss: 0.0049 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0048
# Epoch 129/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0397 - vp_output_loss: 0.0090 - vs_output_loss: 0.0087 - den_output_loss: 0.0055 - val_loss: 0.0332 - val_vp_output_loss: 0.0048 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0048
# Epoch 130/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0394 - vp_output_loss: 0.0088 - vs_output_loss: 0.0087 - den_output_loss: 0.0055 - val_loss: 0.0334 - val_vp_output_loss: 0.0050 - val_vs_output_loss: 0.0073 - val_den_output_loss: 0.0048
# Epoch 131/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0397 - vp_output_loss: 0.0091 - vs_output_loss: 0.0087 - den_output_loss: 0.0058 - val_loss: 0.0331 - val_vp_output_loss: 0.0049 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0049
# Epoch 132/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0391 - vp_output_loss: 0.0087 - vs_output_loss: 0.0082 - den_output_loss: 0.0061 - val_loss: 0.0329 - val_vp_output_loss: 0.0048 - val_vs_output_loss: 0.0073 - val_den_output_loss: 0.0048
# Epoch 133/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0391 - vp_output_loss: 0.0089 - vs_output_loss: 0.0087 - den_output_loss: 0.0056 - val_loss: 0.0327 - val_vp_output_loss: 0.0048 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0048
# Epoch 134/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0386 - vp_output_loss: 0.0088 - vs_output_loss: 0.0086 - den_output_loss: 0.0054 - val_loss: 0.0326 - val_vp_output_loss: 0.0049 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0048
# Epoch 135/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0385 - vp_output_loss: 0.0088 - vs_output_loss: 0.0086 - den_output_loss: 0.0055 - val_loss: 0.0321 - val_vp_output_loss: 0.0047 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0047
# Epoch 136/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0391 - vp_output_loss: 0.0092 - vs_output_loss: 0.0089 - den_output_loss: 0.0055 - val_loss: 0.0325 - val_vp_output_loss: 0.0050 - val_vs_output_loss: 0.0073 - val_den_output_loss: 0.0048
# Epoch 137/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0383 - vp_output_loss: 0.0088 - vs_output_loss: 0.0086 - den_output_loss: 0.0056 - val_loss: 0.0317 - val_vp_output_loss: 0.0047 - val_vs_output_loss: 0.0071 - val_den_output_loss: 0.0047
# Epoch 138/150
# 11/11 [==============================] - 0s 13ms/step - loss: 0.0381 - vp_output_loss: 0.0087 - vs_output_loss: 0.0085 - den_output_loss: 0.0056 - val_loss: 0.0319 - val_vp_output_loss: 0.0048 - val_vs_output_loss: 0.0071 - val_den_output_loss: 0.0048
# Epoch 139/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0377 - vp_output_loss: 0.0087 - vs_output_loss: 0.0083 - den_output_loss: 0.0056 - val_loss: 0.0315 - val_vp_output_loss: 0.0047 - val_vs_output_loss: 0.0071 - val_den_output_loss: 0.0047
# Epoch 140/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0380 - vp_output_loss: 0.0089 - vs_output_loss: 0.0087 - den_output_loss: 0.0055 - val_loss: 0.0318 - val_vp_output_loss: 0.0049 - val_vs_output_loss: 0.0073 - val_den_output_loss: 0.0048
# Epoch 141/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0371 - vp_output_loss: 0.0087 - vs_output_loss: 0.0081 - den_output_loss: 0.0054 - val_loss: 0.0315 - val_vp_output_loss: 0.0048 - val_vs_output_loss: 0.0071 - val_den_output_loss: 0.0048
# Epoch 142/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0368 - vp_output_loss: 0.0085 - vs_output_loss: 0.0081 - den_output_loss: 0.0055 - val_loss: 0.0316 - val_vp_output_loss: 0.0049 - val_vs_output_loss: 0.0073 - val_den_output_loss: 0.0048
# Epoch 143/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0372 - vp_output_loss: 0.0088 - vs_output_loss: 0.0085 - den_output_loss: 0.0053 - val_loss: 0.0311 - val_vp_output_loss: 0.0047 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0047
# Epoch 144/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0373 - vp_output_loss: 0.0086 - vs_output_loss: 0.0086 - den_output_loss: 0.0057 - val_loss: 0.0312 - val_vp_output_loss: 0.0049 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0048
# Epoch 145/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0374 - vp_output_loss: 0.0091 - vs_output_loss: 0.0087 - den_output_loss: 0.0053 - val_loss: 0.0310 - val_vp_output_loss: 0.0047 - val_vs_output_loss: 0.0073 - val_den_output_loss: 0.0047
# Epoch 146/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0372 - vp_output_loss: 0.0089 - vs_output_loss: 0.0086 - den_output_loss: 0.0055 - val_loss: 0.0310 - val_vp_output_loss: 0.0049 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0048
# Epoch 147/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0369 - vp_output_loss: 0.0085 - vs_output_loss: 0.0087 - den_output_loss: 0.0055 - val_loss: 0.0308 - val_vp_output_loss: 0.0048 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0047
# Epoch 148/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0367 - vp_output_loss: 0.0088 - vs_output_loss: 0.0084 - den_output_loss: 0.0054 - val_loss: 0.0309 - val_vp_output_loss: 0.0049 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0048
# Epoch 149/150
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0372 - vp_output_loss: 0.0089 - vs_output_loss: 0.0087 - den_output_loss: 0.0056 - val_loss: 0.0307 - val_vp_output_loss: 0.0049 - val_vs_output_loss: 0.0072 - val_den_output_loss: 0.0048
# Epoch 150/150
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0360 - vp_output_loss: 0.0084 - vs_output_loss: 0.0085 - den_output_loss: 0.0053 - val_loss: 0.0306 - val_vp_output_loss: 0.0048 - val_vs_output_loss: 0.0073 - val_den_output_loss: 0.0048

# %%
# ...existing code...

# 评估模型 - 多输出
eval_results = model3.evaluate(
    X_test, 
    {'vp_output': y_test_vp, 'vs_output': y_test_vs, 'den_output': y_test_den},
    verbose=1
)
print(f'Test Loss: {eval_results}')

# 绘制训练损失和验证损失随 epoch 变化的曲线 - 学术风格
plt.figure(figsize=(22, 5))
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 13

# --- 总损失 ---
plt.subplot(1, 4, 1)
plt.plot(history.history['loss'], 'b-', linewidth=2, label='Training Total Loss', alpha=0.85)
plt.plot(history.history['val_loss'], 'r--', linewidth=2, label='Validation Total Loss', alpha=0.85)
plt.xlabel('Epoch', fontsize=14, fontweight='bold')
plt.ylabel('Loss (MSE)', fontsize=14, fontweight='bold')
plt.title('Total Loss', fontsize=15, fontweight='bold', pad=12)
plt.grid(True, alpha=0.3, linestyle='-', linewidth=0.5)
plt.legend(loc='upper right', frameon=True, fancybox=True, shadow=True, fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_linewidth(1.2)
ax.set_facecolor('#fafafa')

# --- VP输出损失 ---
plt.subplot(1, 4, 2)
plt.plot(history.history['vp_output_loss'], 'b-', linewidth=2, label='Training VP Loss', alpha=0.85)
plt.plot(history.history['val_vp_output_loss'], 'r--', linewidth=2, label='Validation VP Loss', alpha=0.85)
plt.xlabel('Epoch', fontsize=14, fontweight='bold')
plt.ylabel('Loss (MSE)', fontsize=14, fontweight='bold')
plt.title('VP Output Loss', fontsize=15, fontweight='bold', pad=12)
plt.grid(True, alpha=0.3, linestyle='-', linewidth=0.5)
plt.legend(loc='upper right', frameon=True, fancybox=True, shadow=True, fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_linewidth(1.2)
ax.set_facecolor('#fafafa')

# --- VS输出损失 ---
plt.subplot(1, 4, 3)
plt.plot(history.history['vs_output_loss'], 'b-', linewidth=2, label='Training VS Loss', alpha=0.85)
plt.plot(history.history['val_vs_output_loss'], 'r--', linewidth=2, label='Validation VS Loss', alpha=0.85)
plt.xlabel('Epoch', fontsize=14, fontweight='bold')
plt.ylabel('Loss (MSE)', fontsize=14, fontweight='bold')
plt.title('VS Output Loss', fontsize=15, fontweight='bold', pad=12)
plt.grid(True, alpha=0.3, linestyle='-', linewidth=0.5)
plt.legend(loc='upper right', frameon=True, fancybox=True, shadow=True, fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_linewidth(1.2)
ax.set_facecolor('#fafafa')

# --- DEN输出损失 ---
plt.subplot(1, 4, 4)
plt.plot(history.history['den_output_loss'], 'b-', linewidth=2, label='Training DEN Loss', alpha=0.85)
plt.plot(history.history['val_den_output_loss'], 'r--', linewidth=2, label='Validation DEN Loss', alpha=0.85)
plt.xlabel('Epoch', fontsize=14, fontweight='bold')
plt.ylabel('Loss (MSE)', fontsize=14, fontweight='bold')
plt.title('DEN Output Loss', fontsize=15, fontweight='bold', pad=12)
plt.grid(True, alpha=0.3, linestyle='-', linewidth=0.5)
plt.legend(loc='upper right', frameon=True, fancybox=True, shadow=True, fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_linewidth(1.2)
ax.set_facecolor('#fafafa')

plt.tight_layout()

# 保存为高质量PDF
plt.savefig(r"D:\study\deep\老师中期项目\新思路_新模型1021\多输出损失曲线_逆向学术版.pdf",
            format="pdf", dpi=300, bbox_inches='tight', facecolor='white', edgecolor='none')

plt.show()
# ...existing code...
# Out:
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0334 - vp_output_loss: 0.0085 - vs_output_loss: 0.0073 - den_output_loss: 0.0039
# Test Loss: [0.03343130275607109, 0.008549927733838558, 0.007262250874191523, 0.0038768546655774117]

# %%
# Generate test predictions - multi-output
# Make predictions on the test set instead of the entire dataset
predictions = model3.predict(X_test)
vp_predictions = predictions[0]  # VP predictions
vs_predictions = predictions[1]  # VS predictions
den_predictions = predictions[2]  # DEN predictions

# Get the column names for VP, VS, and DEN from the original dataframe
vp_column_name = xie_1.columns[3]  # P-wave_0108 is at index 3
vs_column_name = xie_1.columns[4]  # S-wave_0108 is at index 4
den_column_name = xie_1.columns[1]  # Density_0108 is at index 1

# Inverse transform predictions and labels using stored scalers
vp_scaler = scalers[vp_column_name]
vs_scaler = scalers[vs_column_name]
den_scaler = scalers[den_column_name]

# Reshape for inverse transform
vp_predictions_denorm = vp_scaler.inverse_transform(vp_predictions)
vp_actual_denorm = vp_scaler.inverse_transform(y_test_vp.reshape(-1, 1))

vs_predictions_denorm = vs_scaler.inverse_transform(vs_predictions)
vs_actual_denorm = vs_scaler.inverse_transform(y_test_vs.reshape(-1, 1))

den_predictions_denorm = den_scaler.inverse_transform(den_predictions)
den_actual_denorm = den_scaler.inverse_transform(y_test_den.reshape(-1, 1))
# Out:
# 7/7 [==============================] - 1s 2ms/step

# %%
# Calculate R² scores with denormalized test data
r2_vp = r2_score(vp_actual_denorm, vp_predictions_denorm)
print(f'VP R² Score (denormalized test data): {r2_vp}')

r2_vs = r2_score(vs_actual_denorm, vs_predictions_denorm)
print(f'VS R² Score (denormalized test data): {r2_vs}')

r2_den = r2_score(den_actual_denorm, den_predictions_denorm)
print(f'DEN R² Score (denormalized test data): {r2_den}')

# Plot - VP prediction results with denormalized test data
plt.figure(figsize=(25, 15))
plt.subplot(3, 1, 1)
plt.plot(vp_predictions_denorm, 'r', label='Predicted VP (Test Data)')
plt.plot(vp_actual_denorm, 'k', label='Actual VP (Test Data)')
plt.title('VP Prediction on Test Data using Multi-output STABGCN (Denormalized)')
plt.legend()
plt.ylabel(f'{vp_column_name} values')

# Plot - VS prediction results with denormalized test data
plt.subplot(3, 1, 2)
plt.plot(vs_predictions_denorm, 'b', label='Predicted VS (Test Data)')
plt.plot(vs_actual_denorm, 'g', label='Actual VS (Test Data)')
plt.title('VS Prediction on Test Data using Multi-output STABGCN (Denormalized)')
plt.legend()
plt.ylabel(f'{vs_column_name} values')

# Plot - DEN prediction results with denormalized test data
plt.subplot(3, 1, 3)
plt.plot(den_predictions_denorm, 'm', label='Predicted DEN (Test Data)')
plt.plot(den_actual_denorm, 'y', label='Actual DEN (Test Data)')
plt.title('DEN Prediction on Test Data using Multi-output STABGCN (Denormalized)')
plt.legend()
plt.ylabel(f'{den_column_name} values')

plt.tight_layout()
plt.show()
# Out:
# VP R² Score (denormalized test data): 0.6607493142259189
# VS R² Score (denormalized test data): 0.7420385574771509
# DEN R² Score (denormalized test data): 0.6913080070362942
